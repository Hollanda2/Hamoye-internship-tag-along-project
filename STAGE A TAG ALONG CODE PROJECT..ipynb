# %%
#import needed module
import pandas as pd
url = "FoodBalanceSheets_E_Africa_NOFLAG.csv"
df=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding = "latin1")

# %%
#check the data by displaying the first 5 records
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
#save the data to a csv file named fuel.csv
df.to_csv("fuel.csv")

# %%
fuel_data = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding = "latin1")
fuel_data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
fuel_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
fuel_data.groupby('Y2014')['Y2014'].count()
# Out:
# Y2014
# -1796.0      1
# -1631.0      1
# -849.0       2
# -838.0       1
# -685.0       1
#             ..
#  90425.0     1
#  98094.0     1
#  108756.0    1
#  109593.0    1
#  176405.0    1
# Name: Y2014, Length: 4493, dtype: int64

# %%
fuel_data[['Y2014']] = fuel_data[['Y2014']].fillna(value='-849.0')

# %%
fuel_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014              0
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#Use grouby to count the sum of each unique value
fuel_data.groupby('Item Code')['Item Code'].count()
# Out:
# Item Code
# 2501     90
# 2511    653
# 2513    570
# 2514    687
# 2515    474
#        ...
# 2946    639
# 2948    631
# 2949    571
# 2960    535
# 2961    392
# Name: Item Code, Length: 122, dtype: int64

# %%
fuel_data.groupby('Element Code').first()
# Out:
#               Area Code     Area  Item Code                      Item  \
# Element Code
# 511                   4  Algeria       2501                Population
# 645                   4  Algeria       2905  Cereals - Excluding Beer
# 664                   4  Algeria       2901               Grand Total
# 674                   4  Algeria       2901               Grand Total
# 684                   4  Algeria       2901               Grand Total
# 5072                  4  Algeria       2905  Cereals - Excluding Beer
# 5123                  4  Algeria       2905  Cereals - Excluding Beer
# 5131                  4  Algeria       2905  Cereals - Excluding Beer
# 5142                  4  Algeria       2905  Cereals - Excluding Beer
# 5154                  4  Algeria       2905  Cereals - Excluding Beer
# 5170                  4  Algeria       2905  Cereals - Excluding Beer
# 5171                  7   Angola       2913                  Oilcrops
# ...

# %%
fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True)

# %%
fuel_df2 = fuel_data.iloc[19000:].reset_index(drop=True)

# %%
#check that the length of both dataframes sum to the expected length
assert len(fuel_data) == (len(fuel_df1) + len(fuel_df2))

# %%
pd.merge(fuel_df1, fuel_df2, how="inner")
# Out:
# Empty DataFrame
# Columns: [Area Code, Area, Item Code, Item, Element Code, Element, Unit, Y2014, Y2015, Y2016, Y2017, Y2018]
# Index: []

# %%
pd.merge(fuel_df1, fuel_df2, how="outer")
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
pd.merge(fuel_df1, fuel_df2, how="left")
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 18995        209  Eswatini       2680    Infant food           664
# 18996        209  Eswatini       2680    Infant food           674
# 18997        209  Eswatini       2680    Infant food           684
# 18998        209  Eswatini       2899  Miscellaneous          5611
# 18999        209  Eswatini       2899  Miscellaneous          5072
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
pd.concat([fuel_df1, fuel_df2]).reset_index(drop=True)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
#check for duplicate rows
fuel_data.duplicated().any()
# Out:
# False
